# %% [markdown]
# 1. write a function which will try to find out len of a string without using an inbuilt len function

# %%
def stringlength(my_string):
    counter = 0
    for char in my_string:
        counter += 1
    return counter
stringinput = input("enter string :")
length = stringlength(stringinput)
print("length is ", length

# %% [markdown]
# 2. write a function which  will be able to print an index of list element without using an index function

# %%
index_list = [1,2,3,4,56,67,7,77]

python_indices = []

for i in range(len(index_list)):
    print (i, end = " ")
    print (index_list[i])
# Out:
# 0 1
# 1 2
# 2 3
# 3 4
# 4 56
# 5 67
# 6 7
# 7 77

# %% [markdown]
# 3. write a function which will be able to print an ip address of your system

# %%
import socket
hostname = socket.gethostname()
IPAddr = socket.gethostbyname(hostname)
 
print("Your Computer Name is:" + hostname)
print("Your Computer IP Address is:" + IPAddr)

# %% [markdown]
# 4. write a function which will shutdown your system

# %%
import os
  
shutdown = input("Do you wish to shutdown your computer ? (yes / no): ")
  
if shutdown == 'no':
    exit()
else:
    os.system("shutdown /s /t 1")
# Out:
# Your Computer Name is:venkys-MacBook-Air.local
# Your Computer IP Address is:127.0.0.1

# %% [markdown]
# 5. write a function which will take input as a list with any kind of numeric value and give an out as a multiplication of all the numeric data
#
# l = [3.5, 6.56, 4,5,"sudh" , "ineuron" , 'fsda bootcamp 2.0']

# %%
def multiplyList(myList):
    result = 1
    stringvalues = []
    for x in myList:
        try:
            result *= int(x)
        except:
            stringvalues.append(x)
    return (result,stringvalues)
l = [3.5, 6.56, 4,5,"sudh" , "ineuron" , 'fsda bootcamp 2.0']
multiplyList(l)
# Out:
# (360, ['sudh', 'ineuron', 'fsda bootcamp 2.0'])

# %% [markdown]
# 6. write a function which will be able to read all the mails

# %%
import imaplib
import email

username ="nellorevenky007@gmail.com"
app_password= "lnfmzgarusjvkfug"
gmail_host= 'imap.gmail.com'
mail = imaplib.IMAP4_SSL(gmail_host)
mail.login(username, app_password)
mail.select("INBOX")
_, selected_mails = mail.search(None, '(FROM "noreply@kaggle.com")')
print("Total Messages from noreply@kaggle.com:" , len(selected_mails[0].split()))

for num in selected_mails[0].split():
    _, data = mail.fetch(num , '(RFC822)')
    _, bytes_data = data[0]

    #convert the byte data to message
    email_message = email.message_from_bytes(bytes_data)
    print("\n===========================================")
    print("Subject: ",email_message["subject"])
    print("To:", email_message["to"])
    print("From: ",email_message["from"])
    print("Date: ",email_message["date"])
    for part in email_message.walk():
        if part.get_content_type()=="text/plain" or part.get_content_type()=="text/html":
            message = part.get_payload(decode=True)
            print("Message: \n", message.decode())
            print("==========================================\n")
            break
# Out:
# Total Messages from noreply@kaggle.com: 50
#
# ...
# Subject:  [New Monthly Kaggle Prize] Introducing the Google Open Source Expert Award
# To: nellorevenky007@gmail.com
# From:  Kaggle <noreply@kaggle.com>
# Date:  Tue, 21 Dec 2021 19:22:16 -0800
# Message:
#  Kaggle
#
#
#
#
#
#
#
#
# Hi Samflynn,
#
# We're excited to announce that we're co-sponsoring a new prize with Google
# to support the developer community's usage of Google's open source
# frameworks!
#
#  From January to June 2022, we will award up to three $1000 prizes each
# month to data scientists and ML researchers who share high-quality
# community content (either notebooks or discussions) using JAX, Flax,
# Tensorflow, TF Lite, or Keras.
#
# How it works
#
# 1. Submit a Kaggle notebook or discussion post that demonstrates mastery of
# a Google OSS framework and serves as a resource for other data scientists
# before the month's submission deadline.
# 2. All submissions will be reviewed by the Kaggle team.
# ...

# %% [markdown]
# 7 . write a function which will be able to send a mail to anyone

# %%
import smtplib
from email.message import EmailMessage

email_address = "nellorevenky007@gmail.com"
email_password = "lnfmzgarusjvkfug"
msg = EmailMessage()
msg['Subject'] = "Email subject"
msg['From'] = email_address
msg['To'] = "venky007ios@gmail.com"
msg.set_content("This is eamil message")

# send email
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
    smtp.login(email_address, email_password)
    smtp.send_message(msg)

# %% [markdown]
#
# 8. write a function which will be able to read a doc/word file from your system

# %%
with open('demo.txt','r') as file:
   
    # reading each line    
    for line in file:
   
        # reading each word        
        for word in line.split():
   
            # displaying the words           
            print(word)
# Out:
# hello!
# Welcome
# to
# the
# World

# %%
# Out:
#   Input In [35]
#     pip install docx
#         ^
# SyntaxError: invalid syntax

# %%
pip install docx
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import docx
sampleDoc = docx.Document('sample.docx')

len(sampleDoc.paragraphs)

sampleDoc.paragraphs[0].text
sampleDoc.paragraphs[1].text
sampleDoc.paragraphs[2].text
sampleDoc.paragraphs[3].text
# Out:
# 'Click Insert and then choose the elements you want from the different galleries. Themes and styles also help keep your document coordinated. When you click Design and choose a new Theme, the pictures, charts, and SmartArt graphics change to match your new theme. When you apply styles, your headings change to match the new theme. Save time in Word with new buttons that show up where you need them. To change the way a picture fits in your document, click it and a button for layout options appears next to it. When you work on a table, click where you want to add a row or a column, and then click the plus sign. Reading is easier, too, in the new Reading view. You can collapse parts of the document and focus on the text you want. If you need to stop reading before you reach the end, Word remembers where you left off - even on another device.'
